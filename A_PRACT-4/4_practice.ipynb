# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("data4 - data4.csv")
data
# Out:
#         price  area
# 0    13300000  7420
# 1    12250000  8960
# 2    12250000  9960
# 3    12215000  7500
# 4    11410000  7420
# ..        ...   ...
# 540   1820000  3000
# 541   1767150  2400
# 542   1750000  3620
# 543   1750000  2910
# 544   1750000  3850
#
# [545 rows x 2 columns]

# %%
x = data.iloc[:, :1].values

y = data.iloc[:, 1:2].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
x.shape
# Out:
# (545,)

# %%
x_train.shape
# Out:
# (363,)

# %%
x_test.shape
# Out:
# (182,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_vlaues=regressor.predict(x_test)
y_pred_vlaues
# Out:
# array([[4967.38663591],
#        [5774.37123076],
#        [4656.28276172],
#        [6230.6569129 ],
#        [4081.21196399],
#        [5834.70652758],
#        [4401.7432283 ],
#        [4081.21196399],
#        [4382.88844805],
#        [6796.30032051],
#        [6136.38301163],
#        [4646.8553716 ],
#        [4194.34064551],
#        [4269.75976652],
#        [4722.27449261],
#        [3930.37372196],
#        [4873.11273464],
#        [4496.01712957],
#        [4307.46932703],
#        [4797.69361363],
#        [5193.64399895],
#        [5397.27562569],
#        [5966.68998935],
#        [3515.56855638],
#        [5796.99696707],
#        [5438.75614225],
#        [5623.53298874],
#        [4986.24141616],
#        [5476.46570276],
#        [5702.7230658 ],
#        [4816.54839388],
#        [4458.30756906],
#        [5325.62746073],
#        [4288.61454678],
#        [4492.24617352],
#        [5057.88958113],
#        [7399.65328863],
#        [4382.88844805],
#        [4194.34064551],
#        [4797.69361363],
#        [7324.23416761],
#        [4684.5649321 ],
#        [5589.59438428],
#        [4183.02777736],
#        [4454.53661301],
#        [6570.04295747],
#        [4986.24141616],
#        [4269.75976652],
#        [4741.12927287],
#        [6079.81867087],
#        [4741.12927287],
#        [5023.95097667],
#        [4194.34064551],
#        [4571.43625058],
#        [4269.75976652],
#        [5231.35355946],
#        [6004.39954986],
#        [5589.59438428],
#        [4533.72669008],
#        [5080.51531743],
#        [5137.07965819],
#        [5438.75614225],
#        [4382.88844805],
#        [6551.18817721],
#        [4024.64762323],
#        [5457.6109225 ],
#        [7173.39592558],
#        [4759.98405312],
#        [4759.98405312],
#        [5137.07965819],
#        [4292.38550283],
#        [5834.70652758],
#        [4705.30519038],
#        [6079.81867087],
#        [4590.29103084],
#        [4986.24141616],
#        [3553.27811689],
#        [5966.68998935],
#        [3440.14943536],
#        [4439.45278881],
#        [4269.75976652],
#        [5174.7892187 ],
#        [4982.47046011],
#        [4571.43625058],
#        [4382.88844805],
#        [5787.56957694],
#        [4533.72669008],
#        [5137.07965819],
#        [4420.59800855],
#        [4835.40317413],
#        [4382.88844805],
#        [5891.27086834],
#        [4326.32410729],
#        [4552.58147033],
#        [4609.14581109],
#        [9096.58351145],
#        [4156.631085  ],
#        [7512.78197015],
#        [4797.69361363],
#        [4533.72669008],
#        [5514.17526326],
#        [4269.75976652],
#        [3779.53547993],
#        [5250.20833971],
#        [6079.81867087],
#        [5627.30394479],
#        [4718.50353656],
#        [4156.631085  ],
#        [5476.46570276],
#        [3440.14943536],
#        [3949.22850221],
#        [4043.50240348],
#        [3892.66416145],
#        [4929.6770754 ],
#        [4873.11273464],
#        [4967.38663591],
#        [5325.62746073],
#        [4420.59800855],
#        [4458.30756906],
#        [7776.7488937 ],
#        [4081.21196399],
#        [5774.37123076],
#        [4250.90498627],
#        [5133.30870214],
#        [4194.34064551],
#        [4100.06674424],
#        [6230.6569129 ],
#        [4382.88844805],
#        [5665.01350529],
#        [4382.88844805],
#        [4778.83883337],
#        [4496.01712957],
#        [4684.5649321 ],
#        [3760.68069968],
#        [4948.53185566],
#        [7965.29669624],
#        [4458.30756906],
#        [3930.37372196],
#        [3700.34540286],
#        [3647.55201815],
#        [4801.46456968],
#        [5853.56130783],
#        [5891.27086834],
#        [4609.14581109],
#        [6456.91427595],
#        [7022.55768355],
#        [5306.77268047],
#        [6494.62383645],
#        [5853.56130783],
#        [5137.07965819],
#        [4948.53185566],
#        [4684.5649321 ],
#        [4118.9215245 ],
#        [6453.14331989],
#        [5514.17526326],
#        [6343.78559442],
#        [7965.29669624],
#        [7814.45845421],
#        [4533.72669008],
#        [4081.21196399],
#        [3926.60276591],
#        [4563.89433848],
#        [5061.66053718],
#        [6786.87293038],
#        [4190.56968946],
#        [4382.88844805],
#        [5023.95097667],
#        [4835.40317413],
#        [4929.6770754 ],
#        [3449.38827769],
#        [4156.631085  ],
#        [5702.7230658 ],
#        [5476.46570276],
#        [4194.34064551],
#        [6381.49515493],
#        [4005.79284297],
#        [4137.77630475],
#        [4024.64762323],
#        [3477.85899587],
#        [4364.03366779],
#        [4759.98405312],
#        [5212.49877921]])

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [[0.00053871]]
# [2497.41042268]

# %%
import matplotlib.pyplot as plt

# %%
# visulising training dataset 
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# visualing testing dataset
plt.scatter(x_test,y_test,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
