# %%
import numpy as np
import pandas as pd

# %%
f=pd.read_csv("data1.csv")

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
f.shape
# Out:
# (150, 5)

# %%
f.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
f.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
f.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
f.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
f.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
f.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
f.columns.values
# Out:
# array(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'], dtype=object)

# %%
f.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
f["petal_length"]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
f.sort_values(by="petal_length")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %%
f.iloc[:10,0:]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
f["petal_length"].iloc[5]
# Out:
# 1.7

# %%
f["petal_length"]
f["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
f.iloc[5:10,2:4]
# Out:
#    petal_length  petal_width
# 5           1.7          0.4
# 6           1.4          0.3
# 7           1.5          0.2
# 8           1.4          0.2
# 9           1.5          0.1

# %%
f["sepal_length"]=f["sepal_length"].astype("int")

# %%
f.dtypes
# Out:
# sepal_length      int32
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
f["sepal_length"]=f["sepal_length"].astype("int")

# %%
from sklearn import preprocessing

# %%
x=f.iloc[:,:4]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0               5          3.5           1.4          0.2
# 1               4          3.0           1.4          0.2
# 2               4          3.2           1.3          0.2
# 3               4          3.1           1.5          0.2
# 4               5          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145             6          3.0           5.2          2.3
# 146             6          2.5           5.0          1.9
# 147             6          3.0           5.2          2.0
# 148             6          3.4           5.4          2.3
# 149             5          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
x_scaled=preprocessing.MinMaxScaler().fit_transform(x)
x_scaled
# Out:
# array([[0.33333333, 0.625     , 0.06779661, 0.04166667],
#        [0.        , 0.41666667, 0.06779661, 0.04166667],
#        [0.        , 0.5       , 0.05084746, 0.04166667],
#        [0.        , 0.45833333, 0.08474576, 0.04166667],
#        [0.33333333, 0.66666667, 0.06779661, 0.04166667],
#        [0.33333333, 0.79166667, 0.11864407, 0.125     ],
#        [0.        , 0.58333333, 0.06779661, 0.08333333],
#        [0.33333333, 0.58333333, 0.08474576, 0.04166667],
#        [0.        , 0.375     , 0.06779661, 0.04166667],
#        [0.        , 0.45833333, 0.08474576, 0.        ],
#        [0.33333333, 0.70833333, 0.08474576, 0.04166667],
#        [0.        , 0.58333333, 0.10169492, 0.04166667],
#        [0.        , 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.33333333, 0.83333333, 0.03389831, 0.04166667],
#        [0.33333333, 1.        , 0.08474576, 0.125     ],
# ...

# %%
df_normalized = pd.DataFrame(x_scaled)
df_normalized
# Out:
#             0         1         2         3
# 0    0.333333  0.625000  0.067797  0.041667
# 1    0.000000  0.416667  0.067797  0.041667
# 2    0.000000  0.500000  0.050847  0.041667
# 3    0.000000  0.458333  0.084746  0.041667
# 4    0.333333  0.666667  0.067797  0.041667
# ..        ...       ...       ...       ...
# 145  0.666667  0.416667  0.711864  0.916667
# 146  0.666667  0.208333  0.677966  0.750000
# 147  0.666667  0.416667  0.711864  0.791667
# 148  0.666667  0.583333  0.745763  0.916667
# 149  0.333333  0.416667  0.694915  0.708333
#
# [150 rows x 4 columns]

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0               5          3.5           1.4          0.2     Iris-setosa
# 1               4          3.0           1.4          0.2     Iris-setosa
# 2               4          3.2           1.3          0.2     Iris-setosa
# 3               4          3.1           1.5          0.2     Iris-setosa
# 4               5          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145             6          3.0           5.2          2.3  Iris-virginica
# 146             6          2.5           5.0          1.9  Iris-virginica
# 147             6          3.0           5.2          2.0  Iris-virginica
# 148             6          3.4           5.4          2.3  Iris-virginica
# 149             5          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
f=f.iloc[:,-1]

# %%
label_encoder=preprocessing.LabelEncoder()
enco=label_encoder.fit_transform(f)

# %%
dataframe=pd.DataFrame(enco)
dataframe
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 145  2
# 146  2
# 147  2
# 148  2
# 149  2
#
# [150 rows x 1 columns]

# %%
f.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)
